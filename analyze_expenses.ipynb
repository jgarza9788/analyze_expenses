# %% [markdown]
# # analyze_expenses

# %%
import os
import pandas as pd
# pandas settings
# pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

from IPython.display import display, HTML

# DIR = os.path.dirname(os.path.realpath(__file__))
DIR = os.path.abspath('')
DIR_CSV = os.path.join(DIR,'csv')
# ^ this is where you'll put csv files from your bank's website
DIR_REPORTS = os.path.join(DIR,'reports')
# ^ reports will be saved out here


print('DIR: ', DIR)
print('DIR_CSV: ', DIR_CSV)
print('DIR_REPORTS: ', DIR_REPORTS)
# Out:
# DIR:  c:\Users\JGarza\GitHub\analyze_expenses
# DIR_CSV:  c:\Users\JGarza\GitHub\analyze_expenses\csv
# DIR_REPORTS:  c:\Users\JGarza\GitHub\analyze_expenses\reports

# %% [markdown]
# ## clean csv files
# my bank adds extra lines to the top of the csv files, the code below removes the extra lines.

# %%
# clean csv files

for file in os.listdir(DIR_CSV):
    
    new_file = os.path.join(DIR_CSV,file)
    # print(new_file)

    rewrite = False

    lines = []
    with open(new_file,'r') as f:
        lines = f.readlines()

        remove_rows = []
        for index,l in enumerate(lines):
            # print(index,l)
            if l == 'Date,Description,Amount,Running Bal.\n':
                break
            else:
                remove_rows.append(index)

        for rr in remove_rows:
            del lines[0]
            rewrite = True
    
    if rewrite:
        with open(new_file,'w') as f:
            f.writelines(lines)
# Out:
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt (1).csv
# 0 Date,Description,Amount,Running Bal.
#
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt (2).csv
# 0 Date,Description,Amount,Running Bal.
#
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt (3).csv
# 0 Date,Description,Amount,Running Bal.
#
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt (4).csv
# 0 Date,Description,Amount,Running Bal.
#
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt (5).csv
# 0 Date,Description,Amount,Running Bal.
#
# c:\Users\JGarza\GitHub\analyze_expenses\csv\stmt.csv
# 0 Date,Description,Amount,Running Bal.

# %%
def compile_csv():
    '''
    combines/compiles all csv files
    '''
    df = pd.DataFrame()
    error_lists = []
    for file in os.listdir(DIR_CSV):
        try:
            newfile = os.path.join(DIR_CSV,file)
            df = pd.concat([df, pd.read_csv(newfile)], axis=0)
        except Exception as e:
            error_lists.append('error:, ' + file + ', ' + str(e))
            pass

    # remove duplicates
    df = df.drop_duplicates()

    return df, error_lists

df_raw, errors = compile_csv()

print('rows: ', len(df_raw))
if (len(errors) > 0):
    print('errors:')
    print(*errors,sep='\n')

print('\n***colummns***')
display(df_raw.columns)
print('\n***types***')
display(df_raw.dtypes)

print('\n***top 20***')
display(df_raw.head(20))

# display(df_raw)
# Out:
# rows:  172
#
# ***colummns***
# Index(['Date', 'Description', 'Amount', 'Running Bal.'], dtype='object')
# ***types***
# Date            object
# Description     object
# Amount          object
# Running Bal.    object
# dtype: object
# ***top 20***
#           Date                                        Description    Amount  \
# 0   02/15/2022                 Beginning balance as of 02/15/2022       NaN
# 1   02/15/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...  8,368.91
# 2   02/15/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...    394.94
# 3   02/17/2022  MCDONALD'S M2257 OF CA 02/16 PURCHASE CHATSWOR...    -11.81
# 4   02/18/2022  PAYPAL DES:TRANSFER ID:XXXXX43033560 INDN:JUST...    250.14
# 5   02/18/2022          Netflix.com 02/17 PURCHASE netflix.com CA    -13.99
# 6   02/18/2022  MCDONALD'S M2257 OF CA 02/17 PURCHASE CHATSWOR...    -11.81
# 7   02/18/2022        SMART AND FINA 02/18 PURCHASE CHATSWORTH CA    -37.09
# 8   02/18/2022            VONS #1671 02/18 PURCHASE CHATSWORTH CA    -12.97
# 9   02/22/2022  STARBUCKS STORE 05341 02/17 PURCHASE CHATSWORT...    -15.95
# 10  02/22/2022    TMOBILE*AUTO PAY 02/19 PURCHASE 800-937-8997 WA    -70.00
# 11  02/22/2022   INTUIT *TURBOTAX 02/19 PURCHASE CL.INTUIT.COM CA   -128.00
# 12  02/22/2022     MGD KOREAN BBQ #1 02/19 PURCHASE NORTHRIDGE CA   -119.79
# 13  02/22/2022          Subway 11669 02/20 PURCHASE Chatsworth CA    -13.99
# 14  02/22/2022  TST* PIEOLOGY - LOS ANG 02/20 PURCHASE PORTER ...    -17.74
# 15  02/22/2022  SDC*SEVIER COUNTY ELECT 02/21 PURCHASE XXX-XX3...   -302.23
# 16  02/22/2022          ARCO42255001 02/21 PURCHASE CHATSWORTH CA    -51.66
# 17  02/22/2022             SPOTIFY 02/21 PURCHASE 877-778-1161 NY     -9.99
# 18  02/22/2022        TARGET T- 8840 02/21 PURCHASE Northridge CA    -21.89
# 19  02/22/2022        EARL'S DONUT H 02/22 PURCHASE CHATSWORTH CA     -5.25
#
#    Running Bal.
# 0     17,435.86
# 1     25,804.77
# 2     26,199.71
# 3     26,187.90
# 4     26,438.04
# 5     26,424.05
# 6     26,412.24
# 7     26,375.15
# 8     26,362.18
# 9     26,346.23
# 10    26,276.23
# 11    26,148.23
# 12    26,028.44
# 13    26,014.45
# 14    25,996.71
# 15    25,694.48
# 16    25,642.82
# 17    25,632.83
# 18    25,610.94
# 19    25,605.69
#           Date                                        Description     Amount  \
# 0   02/15/2022                 Beginning balance as of 02/15/2022        NaN
# 1   02/15/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...   8,368.91
# 2   02/15/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...     394.94
# 3   02/17/2022  MCDONALD'S M2257 OF CA 02/16 PURCHASE CHATSWOR...     -11.81
# 4   02/18/2022  PAYPAL DES:TRANSFER ID:XXXXX43033560 INDN:JUST...     250.14
# 5   02/18/2022          Netflix.com 02/17 PURCHASE netflix.com CA     -13.99
# 6   02/18/2022  MCDONALD'S M2257 OF CA 02/17 PURCHASE CHATSWOR...     -11.81
# 7   02/18/2022        SMART AND FINA 02/18 PURCHASE CHATSWORTH CA     -37.09
# 8   02/18/2022            VONS #1671 02/18 PURCHASE CHATSWORTH CA     -12.97
# 9   02/22/2022  STARBUCKS STORE 05341 02/17 PURCHASE CHATSWORT...     -15.95
# 10  02/22/2022    TMOBILE*AUTO PAY 02/19 PURCHASE 800-937-8997 WA     -70.00
# 11  02/22/2022   INTUIT *TURBOTAX 02/19 PURCHASE CL.INTUIT.COM CA    -128.00
# 12  02/22/2022     MGD KOREAN BBQ #1 02/19 PURCHASE NORTHRIDGE CA    -119.79
# 13  02/22/2022          Subway 11669 02/20 PURCHASE Chatsworth CA     -13.99
# 1   01/19/2022  LITTLE CAESARS 5726 Q68 01/17 PURCHASE CHATSWO...      -8.81
# 2   01/19/2022         BEST BUY #130 01/19 PURCHASE NORTHRIDGE CA     -21.89
# 3   01/20/2022   BEST BUY MHT 00001305 01/19 REFUND NORTHRIDGE CA      21.89
# 4   01/20/2022    TMOBILE*AUTO PAY 01/19 PURCHASE 800-937-8997 WA     -70.00
# 5   01/20/2022  SO CAL GAS DES:PAID SCGC ID:XXXXX12425 INDN:XX...     -32.50
# 6   01/21/2022  PAYPAL DES:TRANSFER ID:XXXXX53355226 INDN:JUST...     243.14
# 7   01/21/2022     BURGER KING #5896 01/19 PURCHASE CHATSWORTH CA     -15.97
# 8   01/21/2022         SQ *EPIC TACO 01/20 PURCHASE Sun Valley CA     -13.25
# 9   01/24/2022  BANK OF AMERICA DES:2003PPD_US ID:XXXXXXXXXX24...      70.00
# 10  01/24/2022  AMZN MKTP US*7364J25O3 01/20 PURCHASE AMZN.COM...    -114.77
# 11  01/24/2022  SDC*SEVIER COUNTY ELECT 01/21 PURCHASE XXX-XX3...    -265.35
# 12  01/24/2022             SPOTIFY 01/21 PURCHASE 877-778-1161 NY      -9.99
# 13  01/24/2022  LITTLE CAESARS 5726 Q68 01/21 PURCHASE CHATSWO...      -8.27
# 14  01/24/2022        SMART AND FINA 01/22 PURCHASE CHATSWORTH CA     -38.69
# 15  01/24/2022        SMART AND FINA 01/23 PURCHASE CHATSWORTH CA     -21.37
# 16  01/25/2022            VONS #1671 01/25 PURCHASE CHATSWORTH CA     -26.76
# 17  01/28/2022     BURGER KING #5896 01/26 PURCHASE CHATSWORTH CA     -15.97
# 18  01/28/2022         POPEYES 13357 01/27 PURCHASE CHATSWORTH CA     -13.68
# 19  01/31/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...   2,085.33
# 20  01/31/2022          Subway 11669 01/28 PURCHASE Chatsworth CA     -11.23
# 21  01/31/2022          Subway 11669 01/29 PURCHASE Chatsworth CA     -11.23
# 22  01/31/2022        SMART AND FINA 01/29 PURCHASE CHATSWORTH CA     -59.83
# 23  01/31/2022  SUNTRUST DES:OLB MTGPMT ID:XXXXX73684 INDN:JUS...  -1,060.77
# 24  02/01/2022      CITY OF LA DWP 01/31 PURCHASE 800-432-5397 CA    -227.00
# 25  02/01/2022        WALGREENS STOR 02/01 PURCHASE CHATSWORTH CA     -43.79
# 26  02/02/2022        RITE AID 05545 02/02 PURCHASE CHATSWORTH CA      -8.42
# 27  02/02/2022  MASONGROVE HOMEO DES:MASONGROVE ID:FTXXXXX1798...    -518.00
# 28  02/03/2022  LEMONADE I* LEMONADE I 02/02 PURCHASE LEMONADE...     -48.25
# 29  02/03/2022  NICS BURGERS AND BOWLS 02/02 PURCHASE CHATSWOR...     -15.82
# 30  02/04/2022    PANDA EXPRESS #433 02/03 PURCHASE CHATSWORTH CA     -13.80
# 31  02/04/2022           LAL MIRCH 02/04 PURCHASE AGOURA HILLS CA     -30.23
# 32  02/07/2022  TST* ROBEKS - 306 - CHA 02/03 PURCHASE CHATSWO...      -7.99
# 33  02/07/2022  TST* ROBEKS - 306 - CHA 02/04 PURCHASE CHATSWO...     -10.59
# 34  02/07/2022     BURGER KING #5896 02/05 PURCHASE CHATSWORTH CA     -19.68
# 35  02/07/2022        SMART AND FINA 02/05 PURCHASE CHATSWORTH CA     -80.25
# 36  02/07/2022        WALGREENS STOR 02/06 PURCHASE CHATSWORTH CA      -5.58
# 37  02/07/2022          ARCO42255001 02/07 PURCHASE CHATSWORTH CA      -8.59
# 38  02/08/2022      YOGURTLAND CA306 02/06 PURCHASE CHATSWORTH CA      -8.49
# 39  02/08/2022        SMART AND FINA 02/08 PURCHASE CHATSWORTH CA     -18.72
# 40  02/09/2022        SQ *EPIC TACO 02/08 PURCHASE Los Angeles CA     -12.47
# 41  02/10/2022  MCDONALD'S M2257 OF CA 02/09 PURCHASE CHATSWOR...     -13.00
# 42  02/10/2022            VONS #1671 02/10 PURCHASE CHATSWORTH CA      -6.00
# 43  02/10/2022  MERCURY INS DES:PAYMENT ID:XXXXXXXXXX75026 IND...     -83.27
# 44  02/11/2022  MCDONALD'S M2257 OF CA 02/10 PURCHASE CHATSWOR...     -19.00
# 45  02/14/2022  4TE*SEVIER CO UTILITY D 02/10 PURCHASE 865-453...     -30.05
# 46  02/14/2022  LITTLE CAESARS 5726 Q68 02/11 PURCHASE CHATSWO...      -8.81
# 47  02/14/2022        SMART AND FINA 02/12 PURCHASE CHATSWORTH CA     -60.28
# 48  02/14/2022  HABIT PORTER RANCH 336 02/13 PURCHASE PORTER R...     -13.55
# 49  02/14/2022  SUNTRUST DES:OLB MTGPMT ID:XXXXX73684 INDN:JUS...  -1,060.77
# 50  02/14/2022                                    Interest Earned       0.14
# 0   12/21/2021                 Beginning balance as of 12/21/2021        NaN
# 1   12/21/2021        CICEKS CHICKEN 12/20 PURCHASE CHATSWORTH CA     -19.43
# 2   12/22/2021             SPOTIFY 12/21 PURCHASE 877-778-1161 NY      -9.99
# 3   12/24/2021        CICEKS CHICKEN 12/23 PURCHASE CHATSWORTH CA     -16.41
# 4   12/24/2021        EARL'S DONUT H 12/24 PURCHASE CHATSWORTH CA      -3.00
# 5   12/24/2021        SMART AND FINA 12/24 PURCHASE CHATSWORTH CA      -3.12
# 6   12/27/2021      WM SUPERC Wal- 12/26 PURCHASE PORTER RANCH CA      -1.93
# 7   12/27/2021        SMART AND FINA 12/26 PURCHASE CHATSWORTH CA     -46.53
# 8   12/28/2021  JERSEY MIKES 20311 12/26 PURCHASE PORTER RANCH CA     -20.94
# 9   12/28/2021       Elastum_Simplex 12/27 PURCHASE s@simplex.com     -50.00
# 10  12/28/2021           PAYRANGE MOBILE 12/27 PURCHASE MOBILE XX     -25.00
# 11  12/29/2021        RITE AID 05545 12/29 PURCHASE CHATSWORTH CA     -32.61
# 12  12/31/2021  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...   2,068.88
# 13  01/03/2022          SILVER PANDA 12/31 PURCHASE CHATSWORTH CA     -26.17
# 14  01/03/2022        SMART AND FINA 01/01 PURCHASE CHATSWORTH CA     -59.94
# 15  01/03/2022  LEMONADE I* LEMONADE I 01/02 PURCHASE LEMONADE...     -48.25
# 16  01/03/2022        RITE AID 05545 01/02 PURCHASE CHATSWORTH CA     -12.34
# 17  01/03/2022  SUNTRUST DES:OLB MTGPMT ID:XXXXX73684 INDN:JUS...  -1,060.77
# 18  01/03/2022  MASONGROVE HOMEO DES:MASONGROVE ID:FTXXXXX6273...    -518.00
# 19  01/05/2022         SQ *EPIC TACO 01/04 PURCHASE Sun Valley CA     -13.88
# 20  01/06/2022                                     Counter Credit   1,000.00
# 21  01/07/2022      The Hungry Ninja 01/06 PURCHASE CHATSWORTH CA     -16.82
# 22  01/07/2022        SMART AND FINA 01/07 PURCHASE CHATSWORTH CA     -58.69
# 23  01/10/2022  4TE*SEVIER CO UTILITY D 01/08 PURCHASE 865-453...     -41.48
# 24  01/10/2022     BURGER KING #5896 01/08 PURCHASE CHATSWORTH CA     -15.53
# 25  01/10/2022            VONS #1671 01/09 PURCHASE CHATSWORTH CA      -5.59
# 26  01/11/2022  MCDONALD'S M2257 OF CA 01/10 PURCHASE CHATSWOR...     -17.91
# 27  01/12/2022  AMZN MKTP US*JY68D15O3 01/10 PURCHASE AMZN.COM...     -49.60
# 28  01/13/2022  NICS BURGERS AND BOWLS 01/12 PURCHASE CHATSWOR...     -15.82
# 29  01/13/2022        EARL'S DONUT H 01/13 PURCHASE CHATSWORTH CA      -5.25
# 30  01/13/2022  MERCURY INS DES:PAYMENT ID:XXXXXXXXXX75026 IND...     -83.27
# 31  01/14/2022  BANK OF AMERICA, DES:BANK OF AM ID:XXXXXXXXXX0...   2,085.34
# 32  01/14/2022         APPLE CASH 01/12 PMNT SENT 877-233-8552 CA     -50.00
# 33  01/18/2022     BURGER KING #5896 01/14 PURCHASE CHATSWORTH CA     -19.68
# 34  01/18/2022       CHEVRON/THREE 01/15 PURCHASE PORTER RANCH CA     -50.00
# 35  01/18/2022  LITTLE CAESARS 5726 Q68 01/16 PURCHASE CHATSWO...     -15.33
# 36  01/18/2022  AMAZON.COM*K08JT55I3 AM 01/16 PURCHASE AMZN.CO...     -66.14
# 37  01/18/2022            VONS #1671 01/16 PURCHASE CHATSWORTH CA      -5.09
# 38  01/18/2022          Netflix.com 01/17 PURCHASE netflix.com CA     -13.99
# 39  01/18/2022         POPEYES 13357 01/17 PURCHASE CHATSWORTH CA     -13.68
# 40  01/18/2022            VONS #1671 01/18 PURCHASE CHATSWORTH CA     -10.18
# 41  01/18/2022  SUNTRUST DES:OLB MTGPMT ID:XXXXX73684 INDN:JUS...  -1,060.77
# 42  01/18/2022                                    Interest Earned       0.15
#
#    Running Bal.
# 0     17,435.86
# 1     25,804.77
# 2     26,199.71
# 3     26,187.90
# 4     26,438.04
# 5     26,424.05
# 6     26,412.24
# 7     26,375.15
# 8     26,362.18
# 9     26,346.23
# 10    26,276.23
# 11    26,148.23
# 12    26,028.44
# 13    26,014.45
# 14    25,996.71
# 15    25,694.48
# 16    25,642.82
# 17    25,632.83
# 18    25,610.94
# 19    25,605.69
# 20    25,603.19
# 21    25,567.80
# 22    25,553.02
# 23    25,540.32
# 24    25,479.00
# 25    25,462.81
# 26    25,450.89
# 27    25,444.00
# 28    25,376.09
# 29    24,315.32
# 30    33,044.44
# 31    33,039.95
# 32    33,025.96
# 33    33,024.96
# 34    36,354.96
# 35    36,344.37
# 36    36,328.16
# 37    36,300.68
# 38    49,110.68
# 39    49,155.93
# 40    49,054.64
# 41    49,006.39
# 42    49,000.65
# 43    48,482.65
# 44    48,397.65
# 45    46,821.65
# 46    46,798.11
# 47    46,548.11
# 48    46,507.77
# 49    46,447.72
# 50    46,441.73
# 51    46,427.74
# 52    46,402.66
# 53    46,376.31
# 54    46,345.50
# 55    46,329.63
# 56    45,268.86
# 57    45,185.59
# 58    45,159.45
# 59    45,146.54
# 60    45,106.40
# 61    44,920.26
# 62    44,810.76
# 63    44,796.55
# 64    44,776.86
# 65    43,112.78
# 66    43,077.97
# 67    45,744.79
# 68    45,591.79
# 69    45,751.69
# 70    45,750.69
# 71    45,710.69
# 72    45,064.49
# 73    45,051.58
# 74    45,037.59
# 75    44,830.19
# 76    44,824.94
# 77    44,825.26
# 0     19,208.09
# 1     19,199.28
# 2     19,177.39
# 3     19,199.28
# 4     19,129.28
# 5     19,096.78
# 6     19,339.92
# 7     19,323.95
# 8     19,310.70
# 9     19,380.70
# 10    19,265.93
# 11    19,000.58
# 12    18,990.59
# 13    18,982.32
# 14    18,943.63
# 15    18,922.26
# 16    18,895.50
# 17    18,879.53
# 18    18,865.85
# 19    20,951.18
# 20    20,939.95
# 21    20,928.72
# 22    20,868.89
# 23    19,808.12
# 24    19,581.12
# 25    19,537.33
# 26    19,528.91
# 27    19,010.91
# 28    18,962.66
# 29    18,946.84
# 30    18,933.04
# 31    18,902.81
# 32    18,894.82
# 33    18,884.23
# 34    18,864.55
# 35    18,784.30
# 36    18,778.72
# 37    18,770.13
# 38    18,761.64
# 39    18,742.92
# 40    18,730.45
# 41    18,717.45
# 42    18,711.45
# 43    18,628.18
# 44    18,609.18
# 45    18,579.13
# 46    18,570.32
# 47    18,510.04
# 48    18,496.49
# 49    17,435.72
# 50    17,435.86
# 0     17,636.85
# 1     17,617.42
# 2     17,607.43
# 3     17,591.02
# 4     17,588.02
# 5     17,584.90
# 6     17,582.97
# 7     17,536.44
# 8     17,515.50
# 9     17,465.50
# 10    17,440.50
# 11    17,407.89
# 12    19,476.77
# 13    19,450.60
# 14    19,390.66
# 15    19,342.41
# 16    19,330.07
# 17    18,269.30
# 18    17,751.30
# 19    17,737.42
# 20    18,737.42
# 21    18,720.60
# 22    18,661.91
# 23    18,620.43
# 24    18,604.90
# 25    18,599.31
# 26    18,581.40
# 27    18,531.80
# 28    18,515.98
# 29    18,510.73
# 30    18,427.46
# 31    20,512.80
# 32    20,462.80
# 33    20,443.12
# 34    20,393.12
# 35    20,377.79
# 36    20,311.65
# 37    20,306.56
# 38    20,292.57
# 39    20,278.89
# 40    20,268.71
# 41    19,207.94
# 42    19,208.09
